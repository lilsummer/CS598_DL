# %% [markdown]
# ## Plot figures

# %% [markdown]
# ### Loss Curve 2
# * Corresponding to Version Number: 26
# * Crop center for both train and valid
# * 20 epochs

# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
with open('../cg_experiment/resnet_05e_20_baseline.txt', 'rb') as fb:
    loss = pickle.load(fb)

# %%
loss[:10]
# Out:
# [0.6606999140373807,
#  0.6460158076312532,
#  0.3756744556956821,
#  0.5029037774665077,
#  0.30395419236650106,
#  0.43431087762172005,
#  0.2780909099785545,
#  0.5611799661896181,
#  0.25216961868916965,
#  0.4640861931703552]

# %%
train_loss, val_loss = [], []
for i,v in enumerate(loss):
    if i%2==0:
        train_loss.append(v)
    else:
        val_loss.append(v)
plt.figure(figsize=(8,5))
plt.style.use('seaborn-poster')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(np.arange(20), train_loss, label='train')
plt.plot(np.arange(20), val_loss, label='valid')
plt.legend()
plt.tight_layout()
plt.savefig('loss_curve_resnet_20epochs_new_baseline.pdf')

# %%
loss = [0.6086236234054784,
 0.3908120059821219,
 0.3737531984840357,
 0.2919285285363504,
 0.30359957548799316,
 0.25806280163085427,
 0.2825576856658017,
 0.22759682701997436,
 0.2548548891366043,
 0.2406491306032245,
 0.25142755512920223,
 0.23052877311677378,
 0.24204506797701741,
 0.20353058091726509,
 0.2300901409210015,
 0.2192033236362154,
 0.22660875996218643,
 0.19571780340022632,
 0.214756880290566,
 0.1907215872306707,
 0.18574743455229878,
 0.22229621136954072,
 0.1975478372413398,
 0.2982163106447331,
 0.19164797899075142,
 0.1772863514561901,
 0.18359863347158215,
 0.1808705298725618,
 0.17106259603439145,
 0.178052765112769,
 0.17718957497122748,
 0.23108631970321003,
 0.15470982911295303,
 0.23517356312603033,
 0.17497269602149482,
 0.2434669100181043,
 0.1545167383691959,
 0.24254917911615576,
 0.17344976761588596,
 0.17805689599718158]

# %%
train_loss, val_loss = [], []
for i,v in enumerate(loss):
    if i%2==0:
        train_loss.append(v)
    else:
        val_loss.append(v)
plt.figure(figsize=(8,5))
plt.style.use('seaborn-poster')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.plot(np.arange(20), train_loss, label='train')
plt.plot(np.arange(20), val_loss, label='valid')
plt.legend()
plt.tight_layout()
plt.savefig('loss_curve_resnet_pipeline1.pdf')

# %% [markdown]
# ### PR curve

# %%
import pandas as pd

# %% [markdown]
# #### ResNet

# %%
baseline = pd.read_csv('../cg_experiment/pc_curve_0420_baseline_resize_3.csv')
crop = pd.read_csv('../cg_experiment/pc_curve_res_crop.csv')
distor = pd.read_csv('../cg_experiment/pc_curve_0420_distort_3.csv')
zoom = pd.read_csv('../cg_experiment/pc_curve_res_zoom.csv')

# %%
plt.figure(figsize=(8,5))
plt.plot(baseline.recall, baseline.precision, label='base', linewidth=1)
plt.plot(zoom.recall, zoom.precision, label='zoom',linewidth=1)
plt.plot(crop.recall, crop.precision, label='crop', linewidth=1)
plt.plot(distor.recall, distor.precision, label='distortion', linewidth=1)
plt.legend()
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.title('resNet50')
plt.tight_layout()

plt.savefig('resnet_pr_curve.pdf')

# %% [markdown]
# ### SqueezeNet

# %%
baseline = pd.read_csv('../cg_experiment/pc_curve_0420_squeezenet_base.csv')
crop = pd.read_csv('../cg_experiment/pc_curve_0420_squeezenet_crop.csv')
distor = pd.read_csv('../cg_experiment/pc_curve_0420_squeezenet_distort.csv')
zoom = pd.read_csv('../cg_experiment/pc_curve_0420_squeezenet_zoom.csv')

# %%
plt.figure(figsize=(8,5))
plt.plot(baseline.recall, baseline.precision, label='base', linewidth=1)
plt.plot(zoom.recall, zoom.precision, label='zoom', linewidth=1)
plt.plot(crop.recall, crop.precision, label='crop', linewidth=1)
plt.plot(distor.recall, distor.precision, label='distortion', linewidth=1)
plt.legend()
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.title('SqueezeNet')
plt.tight_layout()

plt.savefig('squeeze_pr_curve.pdf')

# %% [markdown]
# #### SqueezeNet Averge

# %%
baseline_a = pd.read_csv('../cg_experiment/pc_curve_0420_squeezenet_c3.csv')
baseline_b = pd.read_csv('../cg_experiment/pc_curve_0420_squeezenet_c3_2.csv')

zoom_a = pd.read_csv('../cg_experiment/pc_curve_0420_squeezenet_zoom_1.csv')
zoom_b = pd.read_csv('../cg_experiment/pc_curve_0420_squeezenet_zoom_2.csv')

# %%
baseline_a.shape, baseline_b.shape
# Out:
# ((7853, 2), (7117, 2))

# %%
plt.figure(figsize=(8,5))
plt.plot(baseline_a.recall, baseline_a.precision)
plt.plot(baseline_b.recall, baseline_b.precision)
plt.plot(zoom_a.recall, zoom_a.precision)
plt.plot(zoom_b.recall, zoom_b.precision)

# %% [markdown]
# #### Densenet

# %%
baseline = pd.read_csv('../cg_experiment/pc_curve_0420_densenet_3c.csv')
crop = pd.read_csv('../cg_experiment/pc_curve_0420_densenet_crop_1.csv')
distor = pd.read_csv('../cg_experiment/pc_curve_0420_densenet_distort_1.csv')
zoom = pd.read_csv('../cg_experiment/pc_curve_0420_densenet_zoom_1.csv')

# %%
plt.figure(figsize=(8,5))
plt.plot(baseline.recall, baseline.precision, label='base', linewidth=1)
plt.plot(zoom.recall, zoom.precision, label='zoom', linewidth=1)
plt.plot(crop.recall, crop.precision, label='crop', linewidth=1)
plt.plot(distor.recall, distor.precision, label='distortion', linewidth=1)
plt.legend()
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.title('DenseNet121')
plt.tight_layout()

plt.savefig('densenet_pr_curve.pdf')

# %% [markdown]
# ### All baseline

# %%
dense_baseline = pd.read_csv('../cg_experiment/pc_curve_0420_densenet_3c.csv')
squee_baseline = pd.read_csv('../cg_experiment/pc_curve_0420_squeezenet_base.csv')
res_baseline = pd.read_csv('../cg_experiment/pc_curve_0420_baseline_resize_3.csv')

# %%
plt.figure(figsize=(8,5))

plt.plot(res_baseline.recall, res_baseline.precision, label='ResNet', linewidth=1)
plt.plot(squee_baseline.recall, squee_baseline.precision, label='SqueezeNet', linewidth=1)
plt.plot(dense_baseline.recall, dense_baseline.precision, label='DenseNet', linewidth=1)
plt.title('Baseline Comparison')
plt.legend()
plt.tight_layout()
plt.savefig('pr_all_base.pdf')

# %% [markdown]
# ### One cycle learning

# %%
sched1 = pd.read_csv('../cg_experiment/pc_curve_onecycle_sched_1.csv')

# %%
sched3 = pd.read_csv('../cg_experiment/pc_curve_onecycle_sched_3.csv')
sched4= pd.read_csv('../cg_experiment/pc_curve_onecycle_sched_4.csv')
distor = pd.read_csv('../cg_experiment/pc_curve_0420_distort_3.csv')

# %%
plt.figure(figsize=(8,5))

plt.plot(sched1.recall, sched1.precision, label='sched1', linewidth=1)
plt.plot(sched3.recall, sched3.precision, label='sched3', linewidth=1)
plt.plot(sched4.recall, sched4.precision, label='sched4', linewidth=1)
plt.plot(distor.recall, distor.precision, label='Distortion', linewidth=1)
plt.ylabel('Precision')
plt.xlabel('Recall')
plt.legend()
plt.tight_layout()
plt.savefig('pr_onecycle.pdf')

# %% [markdown]
# ## one cycle sched1

# %%
sched1 = pd.read_csv('version_10_1cycle_sched1.csv')

# %%
plt.figure(figsize=(8,5))
plt.plot(sched1.Epoch, sched1.Train,)
plt.plot(sched1.Epoch, sched1.Validate)

# %%
sched2 = pd.read_csv('version_9_1cycle_sched2.csv')

# %%
plt.figure(figsize=(15,5))
plt.style.use('seaborn-poster')
plt.subplot(1,2,1)
plt.plot(sched1.Epoch, sched1.Train,label='train')
plt.plot(sched1.Epoch, sched1.Validate,label='valid')
plt.text(6.3, 1.3, 'spike', fontsize=15, color='red')
plt.ylabel('loss')
plt.xlabel('epoch')

plt.title('Schedule 1')
plt.legend()
plt.subplot(1,2,2)
plt.plot(sched2.Epoch, sched2.Train,label='train')
plt.plot(sched2.Epoch, sched2.Validation,label='valid')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.title('Schdule 2')
plt.legend()
plt.savefig('1cycle_sched12_loss.pdf')
